# %% [markdown]
# **Data Analysis process:**
# 1. Asking questions
# 2. Data wrangling: Gathering, Accessing and Cleaning
# 3. EDA: exploratory data analysis
# 4. Drawing conclusion
# 5. Communicating Result

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Your notebook/file can be inside the data analysis folder while your datasets are inside a separate datasets folder. Pandas can read them without any problem. for this use ".." means:Go to the parent folder (one folder back).**

# %% [markdown]
# **IMPORT DATASETS**

# %% [markdown]
# **1. Import from csv file**

# %%
df = pd.read_csv("../datasets/aug_train.csv")
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# **a. sep parameter:** from tsv(tab seperator value) file: for that we use "sep" parameter which us used to seperate the column on the basis of tab

# %%
pd.read_csv("../datasets/movie_titles_metadata.tsv") #as this is very raw data and we dont know exact value in column as they are seperated by tab not comma
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
pd.read_csv("../datasets/movie_titles_metadata.tsv", sep = "\t")  #|t is used for tab and also as table mein 1st row hi column ban gyi , to aap custom index banadoge ek list pass krke jisme different column honge us list mein
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
pd.read_csv("../datasets/movie_titles_metadata.tsv", sep = "\t", names= ["s.no", "title", "year", "IMDB_rating", "votes", "genre"], index_col = "s.no")
# Out:
#                            title  year  IMDB_rating     votes  \
# s.no
# m0    10 things i hate about you  1999          6.9   62847.0
# m1    1492: conquest of paradise  1992          6.2   10421.0
# m2                    15 minutes  2001          6.1   25854.0
# m3         2001: a space odyssey  1968          8.4  163227.0
# m4                       48 hrs.  1982          6.9   22289.0
# ...                          ...   ...          ...       ...
# m612                    watchmen  2009          7.8  135229.0
# m613                         xxx  2002          5.6   53505.0
# m614                       x-men  2000          7.4  122149.0
# m615          young frankenstein  1974          8.0   57618.0
# m616                   zulu dawn  1979          6.4    1911.0
#
#                                                   genre
# s.no
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# **b. index_col parameter:** : agar ek extra column add ho jaye to aap custom column ko bhi index column banaskte ho

# %%
pd.read_csv("../datasets/aug_train.csv") #like here s.no and enrolle is ko ek column mein likh skte hain
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv("../datasets/aug_train.csv", index_col = "enrollee_id")
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# **c. header parameter:**

# %%
pd.read_csv("../datasets/test1.csv")  # 1st row column ka naam hai, lekin yeh column headers hai to ise column mein convert krna to to specify krna hai
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
pd.read_csv("../datasets/test1.csv", header =1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# **d. use_col parameter:**

# %%
pd.read_csv("../datasets/aug_train.csv", usecols= ["enrollee_id", "gender", "education_level"])  #ab yeh possibility ho skti hai ki aap ko saare columns nhi balki kuch columns hi xhaahiye ho to aap yeh parametr use kr skte ho
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# **e. skip rows parameter:**

# %%
pd.read_csv("../datasets/aug_train.csv", skiprows = [0,1,3])  # like if you want to skip 1,2 and 4th row from table use can choose their indexes for removal
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      33241  city_115               0.789   NaN   No relevent experience
# 1        666  city_162               0.767  Male  Has relevent experience
# 2      21651  city_176               0.764   NaN  Has relevent experience
# 3      28806  city_160               0.920  Male  Has relevent experience
# 4        402   city_46               0.762  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19150   7386  city_173               0.878  Male   No relevent experience
# 19151  31398  city_103               0.920  Male  Has relevent experience
# 19152  24576  city_103               0.920  Male  Has relevent experience
# 19153   5756   city_65               0.802  Male  Has relevent experience
# 19154  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM   15    50-99  \
# ...

# %% [markdown]
# **f. nrows:**

# %%
pd.read_csv("../datasets/aug_train.csv", nrows = 100)  #as total 9000 rows but aapne restrict krdiya 100 rows, it works when dataset is very huge like lakhs of rows which occpy memory so you avoid it by taking 100 only
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# **g. encoding parameter:**

# %%
pd.read_csv("../datasets/zomato.csv")  # as it shows UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 7044: invalid continuation byte in very last line because aapka encoding: UTF-8 nhi hai, so app kisi inline encoding editor mein jaake uski encoding change kr skte ho
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.read_csv("../datasets/zomato.csv")  # as it shows UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 7044: invalid continuation byte in very last line because aapka encoding: UTF-8 nhi hai, so app kisi inline encoding editor mein jaake uski encoding change kr skte ho
#
# ...

# %%
pd.read_csv("../datasets/zomato.csv", encoding = "latin-1")
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# **h. dtype:** to change datatype

# %%
pd.read_csv("../datasets/aug_train.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
#as last column named target mein hamein flot nhi int chaahiye tha so hum change kr skte hain do hum yeh dictionary meinpaas kr denge

pd.read_csv("../datasets/aug_train.csv", dtype={"target": int}).info() # now target columnn changes to int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %% [markdown]
# **i. handling date: very imp topic**

# %%
pd.read_csv("../datasets/IPL Matches 2008-2020.csv").info()  #as in this, date column is object jo ki string hota hai pandas ke liye to ise date format mein change krna hoga
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv("../datasets/IPL Matches 2008-2020.csv", parse_dates=["date"]).info() #now you check yeh datetime64[ns] mein change ho gya
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# **g. load huge dat into chunks:**

# %%
dfs = pd.read_csv("../datasets/aug_train.csv", chunksize = 5000) #as this data set have 19000 rows so humne use 5000 ke chuinks mein devide krdiya

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (4158, 14)

# %% [markdown]
# **2. import from excel file:**

# %%
pd.read_excel("../datasets/clinical_trials.xlsx")
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %% [markdown]
# as you file in excel you came to know that this file has 4 sheets if you want to fetch another sheet kyunki upar sheet 1 named "patients" ka data hai

# %%
pd.read_excel("../datasets/clinical_trials.xlsx", sheet_name="treatments")
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0             NaN
# 1            0.97
# ...

# %% [markdown]
# **3. import from json file:**

# %%
pd.read_json("../datasets/train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# **4. import from sql file:**
#
# **uske liye "xampp" software download and install kro and apache & mysql bench ko run kro and then new tab mein jaake**
# **localhost/phpmyadmin/ daalo link pe to page open ho jaayega and then create database named "world" and then import file jisme yeh sql data hai**

# %%
# !pip install mysql.connector

# %%
import mysql.connector  #this library is used to communicate between python and sql, act like a bridge between sql and python

# %%
conn = mysql.connector.connect(host="localhost", user="root",password= "",database = "world") #it give object named MySQLConnection which uis stored in conn jispe aap aage work kroge
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 conn = mysql.connector.connect(host="localhost", user="root",password= "",database = "world") #it give object named MySQLConnection which uis stored in conn jispe aap aage work kroge
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
# ...

# %%
pd.read_sql_query("select * from city where CountryCode = 'IND'",conn)  #hamne filter kr diya sirf india mein
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pd.read_sql_query("select * from city where CountryCode = 'IND'",conn)  #hamne filter kr diya sirf india mein
#
# NameError: name 'conn' is not defined
